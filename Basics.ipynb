# %% [markdown]
# # Movies_Project.

# %%
import pandas as pd
import numpy as np

# %%
#t_basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
basics= pd.read_csv(t_basics_url, sep ='\t', low_memory =False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %% [markdown]
# Filtering out movies with null values in genre or runtime

# %%
#Converting the \N null value into a pandas recognizable format of np.nan
basics =basics.replace({"\\N":np.nan})

# %% [markdown]
# Checking the null values

# %%
basics.isnull().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1182517
# endYear           8783997
# runtimeMinutes    6482276
# genres             404554
# dtype: int64

# %%
#Dropping null values in genre and runtime
basics = basics.dropna(subset=['genres', 'runtimeMinutes'])

# %%
#Confirming changes
basics.isnull().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            0
# originalTitle           0
# isAdult                 0
# startYear           34155
# endYear           2282294
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %% [markdown]
# Filtering only movies with full-length (titleType = "movie")

# %%
basics = basics[basics["titleType"] == 'movie']

# %%
#Confirming changes
basics.head(5)
# Out:
#          tconst titleType                    primaryTitle  \
# 570   tt0000574     movie     The Story of the Kelly Gang
# 587   tt0000591     movie                The Prodigal Son
# 672   tt0000679     movie  The Fairylogue and Radio-Plays
# 1172  tt0001184     movie         Don Juan de Serrallonga
# 1273  tt0001285     movie               The Life of Moses
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 570      The Story of the Kelly Gang       0      1906     NaN             70
# 587                L'enfant prodigue       0      1907     NaN             90
# 672   The Fairylogue and Radio-Plays       0      1908     NaN            120
# 1172         Don Juan de Serrallonga       0      1910     NaN             58
# 1273               The Life of Moses       0      1909     NaN             50
#
#                           genres
# 570   Action,Adventure,Biography
# 587                        Drama
# 672            Adventure,Fantasy
# 1172             Adventure,Drama
# 1273      Biography,Drama,Family

# %% [markdown]
# Filtering only movies that were released between 2000 and 2021(2000, and 2021 inclusive)

# %%
basics['startYear'] = basics['startYear'].astype(int)

# %%
basics['startYear'] >=2000
# Out:
# 570        False
# 587        False
# 672        False
# 1172       False
# 1273       False
#            ...
# 8873593     True
# 8873677     True
# 8873718     True
# 8873745     True
# 8873778     True
# Name: startYear, Length: 359011, dtype: bool

# %%
basics['startYear'] <=2021
# Out:
# 570        True
# 587        True
# 672        True
# 1172       True
# 1273       True
#            ...
# 8873593    True
# 8873677    True
# 8873718    True
# 8873745    True
# 8873778    True
# Name: startYear, Length: 359011, dtype: bool

# %%
basics = basics[(basics['startYear'] >=2000 ) & (basics['startYear'] <=2021)]

# %%
#Confirming changes
basics.tail(10)
# Out:
#             tconst titleType              primaryTitle  \
# 8872616  tt9914192     movie       No Gogó do Paulinho
# 8872657  tt9914286     movie         Sokagin Çocuklari
# 8872913  tt9914828     movie       The War of Godzilla
# 8872964  tt9914942     movie    Life Without Sara Amat
# 8873360  tt9915872     movie      The Last White Witch
# 8873500  tt9916170     movie             The Rehearsal
# 8873509  tt9916190     movie                 Safeguard
# 8873548  tt9916270     movie  Il talento del calabrone
# 8873593  tt9916362     movie                     Coven
# 8873677  tt9916538     movie       Kuambil Lagi Hatiku
#
#                       originalTitle isAdult  startYear endYear runtimeMinutes  \
# 8872616         No Gogó do Paulinho       0       2020     NaN             98
# 8872657           Sokagin Çocuklari       0       2019     NaN             98
# 8872913         The War of Godzilla       0       2015     NaN            102
# 8872964  La vida sense la Sara Amat       0       2019     NaN             74
# 8873360   My Girlfriend is a Wizard       0       2019     NaN             97
# 8873500                    O Ensaio       0       2019     NaN             51
# 8873509                   Safeguard       0       2020     NaN             90
# 8873548    Il talento del calabrone       0       2020     NaN             84
# 8873593                    Akelarre       0       2020     NaN             92
# 8873677         Kuambil Lagi Hatiku       0       2019     NaN            123
#
#                             genres
# 8872616                     Comedy
# 8872657               Drama,Family
# 8872913       Action,Comedy,Family
# 8872964                      Drama
# 8873360       Comedy,Drama,Fantasy
# 8873500                      Drama
# 8873509  Action,Adventure,Thriller
# 8873548                   Thriller
# 8873593              Drama,History
# 8873677                      Drama

# %% [markdown]
# **Filtering only fictional movies(not from documentary genre)**

# %%
non_documentary = basics['genres'].str.contains('Documentary', case = False)

# %%
basics = basics[~non_documentary]

# %%
#confirming changes
basics.tail()
# Out:
#             tconst titleType              primaryTitle  \
# 8873500  tt9916170     movie             The Rehearsal
# 8873509  tt9916190     movie                 Safeguard
# 8873548  tt9916270     movie  Il talento del calabrone
# 8873593  tt9916362     movie                     Coven
# 8873677  tt9916538     movie       Kuambil Lagi Hatiku
#
#                     originalTitle isAdult  startYear endYear runtimeMinutes  \
# 8873500                  O Ensaio       0     2019.0     NaN             51
# 8873509                 Safeguard       0     2020.0     NaN             90
# 8873548  Il talento del calabrone       0     2020.0     NaN             84
# 8873593                  Akelarre       0     2020.0     NaN             92
# 8873677       Kuambil Lagi Hatiku       0     2019.0     NaN            123
#
#                             genres
# 8873500                      Drama
# 8873509  Action,Adventure,Thriller
# 8873548                   Thriller
# 8873593              Drama,History
# 8873677                      Drama

# %% [markdown]
# **Saving the filtered basics dataset temporary as a .csv file**

# %%
basics.to_csv("Title_Basics.csv", index =False)

# %%
#confirming saved file
df = pd.read_csv("Title_Basics.csv")
df.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                              November 1828        0     2001.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %% [markdown]
# **The Title_Basic file was successfully saved**
