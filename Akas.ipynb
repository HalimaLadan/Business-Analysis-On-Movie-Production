# %% [markdown]
# # Movies_Project

# %%
#Importing libraries
import pandas as pd
import numpy as np

# %%
#Assigning the data file url to a variable
#t_akas_url ="https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
#Loading the data file
akas= pd.read_csv(t_akas_url, sep ='\t', low_memory =False)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %% [markdown]
# **Filtering only US enteries**

# %%
akas =akas.loc[akas["region"]=="US"]

# %%
#Confirming changes
akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US       \N  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 33  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#                attributes isOriginalTitle
# 5                      \N               0
# 14  literal English title               0
# 33                     \N               0
# 36                     \N               0
# 41                     \N               0

# %% [markdown]
# **Converting the \N null value format into np.nan**

# %%
#Converting the \N null value format into np.nan
Title_Akas =akas.replace({"\\N":np.nan})

# %%
#Confirming changes
Title_Akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %% [markdown]
# **Loading and filtring the Basics table to include only the US tables filtered in the akas dataframe.**

# %%
#Loading the basics file
basics = pd.read_csv("Title_Basics.csv")
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                              November 1828        0     2001.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
#Filtering the basics file to include only US movies
keepers = basics['tconst'].isin(akas["titleId"])
keepers.head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: tconst, dtype: bool

# %%
Title_Basics= basics[keepers]
Title_Basics.head()
# Out:
# C:\Users\heill\anaconda3\envs\dojo-env\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
# 7  tt0093119     movie                                Grizzly II: Revenge
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# ...

# %% [markdown]
# **Creating a folder to save the filtered files**

# %%
import os
os.makedirs('Movies_Data/', exist_ok =True)

# %%
akas.to_csv ("Movies_files/Title_Akas.csv.gz", compression = "gzip", index = False)

# %%
Title_Basics.to_csv ("Movies_files/Title_Basics.csv.gz", compression = "gzip", index = False)

# %% [markdown]
# **Checking to see if files were saved successfully**

# %%
#Confirming changes
basics = pd.read_csv("Movies_files/Title_Basics.csv.gz")
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0093119     movie                                Grizzly II: Revenge
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                   Grizzly II: The Predator        0     2020.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
akas = pd.read_csv("Movies_files/Title_Akas.csv.gz")
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %% [markdown]
# **Files were saved successfully**
